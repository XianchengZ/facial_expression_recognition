# %%
from utils import getData
from ann_model import ANN

# %%
Xtrain, Ytrain, Xtest, Ytest = getData()

# %%
model = ANN(200)
model.fit(Xtrain, Ytrain, Xtest, Ytest, reg=0, show_fig=True)
print(model.score(Xvalid, Yvalid))
# Out:
# i: 0 cost: 2.1869201582736166 error: 0.7527376076235058
# i: 10 cost: 1.829655118682278 error: 0.7512329683189836
# i: 20 cost: 1.8180906180077738 error: 0.7489760093622001
# i: 30 cost: 1.8071116950316233 error: 0.750062693304355
# i: 40 cost: 1.7982498816668098 error: 0.7444620914486333
# i: 50 cost: 1.799777296486112 error: 0.7515673326088774
# i: 60 cost: 1.799858406140205 error: 0.7448800468110006
# i: 70 cost: 1.7921420526232466 error: 0.7410348574772214
# i: 80 cost: 1.7885684795185417 error: 0.7355178466939731
# i: 90 cost: 1.7977004539336379 error: 0.7541586558555546
# i: 100 cost: 1.8003640661777927 error: 0.7446292735935802
# i: 110 cost: 1.792814410823358 error: 0.7445456825211068
# i: 120 cost: 1.7894867259541718 error: 0.7372732592159157
# i: 130 cost: 1.7893174178369384 error: 0.7467190504054168
# i: 140 cost: 1.7804612237791164 error: 0.7328429323748223
# i: 150 cost: 1.7944881824118846 error: 0.7578366630443869
# ...
